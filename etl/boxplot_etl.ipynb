# %%
import pandas as pd
import matplotlib.pyplot as plt
import pandas as pd
from statistics import quantiles


# Leggi il file CSV e carica in un DataFrame
df = pd.read_csv('../raw_datasets/middle_east_aggregated_data.csv', delimiter=';')

# %%
df = df[["WEEK", "COUNTRY", "EVENT_TYPE", "SUB_EVENT_TYPE", "EVENTS"]]
df.head()
# Out:
#                WEEK  COUNTRY                  EVENT_TYPE  \
# 0  06-febbraio-2016  Bahrain                     Battles
# 1    25-giugno-2016  Bahrain  Explosions/Remote violence
# 2  11-febbraio-2017  Bahrain  Explosions/Remote violence
# 3  18-febbraio-2017  Bahrain  Explosions/Remote violence
# 4    12-agosto-2017  Bahrain  Explosions/Remote violence
#
#                   SUB_EVENT_TYPE  EVENTS
# 0                    Armed clash       1
# 1  Remote explosive/landmine/IED       1
# 2  Remote explosive/landmine/IED       2
# 3  Remote explosive/landmine/IED       1
# 4  Remote explosive/landmine/IED       1

# %%
from pathlib import Path


df.to_csv("../datasets/mea_boxplot_data.csv", index=False)
